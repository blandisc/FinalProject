# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False, user_agent="Mozilla/5.0 (iPhone; U; CPU like Mac OS X; en)")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-3-d686de8d1a61> in <module>
#       1 executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
# ----> 2 browser = Browser('chrome', **executable_path, headless=False, user_agent="Mozilla/5.0 (iPhone; U; CPU like Mac OS X; en)")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/splinter/browser.py in Browser(driver_name, retry_count, *args, **kwargs)
#      88         raise DriverNotFoundError("No driver for %s" % driver_name)
#      89
# ---> 90     return get_driver(driver, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/splinter/browser.py in get_driver(driver, retry_count, *args, **kwargs)
#      66             pass
#      67
# ---> 68     raise e
#      69
#      70
#
# UnboundLocalError: local variable 'e' referenced before assignment

# %%
url = "https://mobile.twitter.com/search?q=%28to%3Alopezobrador_%29+until%3A2020-09-31+since%3A2020-08-01+-filter%3Alinks&s=typd&x=0&y=0"

browser.visit(url)

browser.html

soup = bs(browser.html, 'html.parser')

tweets_responses =[]

tweets_body = soup.find_all("tbody")

tweets_body1 = tweets_body[6:]

for tweet in tweets_body1:

        tweetContent = tweet.find_all('div', class_='dir-ltr')[0].text.strip()

        tweetDate = tweet.find_all('td', class_='timestamp')[0].a.text
        
        tweetUser = tweet.find_all('div', class_='username')[0].text.strip()
        
        tweets_responses.append({"Content" : tweetContent, "Date" : tweetDate, "User": tweetUser })

while True:
    try:
        browser.find_by_text('Cargar Tweets antiguos ').click()
        
        browser.html

        soup = bs(browser.html, 'html.parser')

        tweets_body = soup.find_all("tbody")

        tweets_body1 = tweets_body[6:]

        for tweet in tweets_body1:

            tweetContent = tweet.find_all('div', class_='dir-ltr')[0].text.strip()

            tweetDate = tweet.find_all('td', class_='timestamp')[0].a.text
        
            tweetUser = tweet.find_all('div', class_='username')[0].text.strip()
        
            tweets_responses.append({"Content" : tweetContent, "Date" : tweetDate, "User": tweetUser })
        
    except: 
        break
        
df = pd.DataFrame(tweets_responses)
df.sort_values(by=["Date"])

# %%
df
# Out:
#                                                Content     Date  \
# 0                    Que no era un estado laico y así?  25 ago.
# 1                                     Tu no eres bueno  25 ago.
# 2    Eres nuestro rey, emperador,  nuestro sensei, ...  26 ago.
# 3    Exacto.dios lo bendiga.ud.ya es historia,dios ...  25 ago.
# 4             ¿Estás de acuerdo con la transformación?  26 ago.
# ..                                                 ...      ...
# 827  @lopezobrador_ Y vemos en tv cualquier cantida...   1 ago.
# 828  @lopezobrador_ La trata  de personas vemos un ...   1 ago.
# 829  @lopezobrador_ debe estar muy orgulloso por ha...   1 ago.
# 830  @lopezobrador_ anunciará el 15 de Septiembre q...   1 ago.
# 831  @lopezobrador_  tienes cuatro meses por delant...   1 ago.
#
#                  User
# 0      @Brigitte_Grey
# 1       @juancarlosgt
# 2           @KAndrids
# 3     @jceciliatorres
# 4            @vampipe
# ..                ...
# 827  @YOSOYIZQUIERDA2
# 828  @YOSOYIZQUIERDA2
# 829      @TaCabronNo1
# 830       @ElGuyTrejo
# 831     @ErnestoBNava
#
# [832 rows x 3 columns]

# %%
df[df.Date == "25 ago."]
# Out:
#                                               Content     Date  \
# 0                   Que no era un estado laico y así?  25 ago.
# 1                                    Tu no eres bueno  25 ago.
# 3   Exacto.dios lo bendiga.ud.ya es historia,dios ...  25 ago.
# 5                        "Tengan para que aprendan" 💖  25 ago.
# 8   Eres un corruptazo y vividor. Ni siquiera paga...  25 ago.
# 11              ¿No es MUY conservador citar al Papa?  25 ago.
# 12                                     Puto mediocre!  25 ago.
# 25              Cómo engaña a la gente el idiota este  25 ago.
# 26  PUES NO TE CREO NADA PORQUE NO RESPETAS NI CUM...  25 ago.
# 27  Las ocurrencias idiotas solo pueden provenir d...  25 ago.
# 28  Ni es humanista. \nNi es católico.\nNi es hone...  25 ago.
# 29    No los está ayudando... los está matando‼️‼️🇲🇽🖤  25 ago.
# 30  Usted es muy bueno sr. Presidente, pero bueno ...  25 ago.
# 31  ¡Qué espectáculo tan denigrante!\n\nQue notori...  25 ago.
# 32  -Más de 60,000 muertos por una mala gestión de...  25 ago.
# 33  Farsante, los niños con cáncer siguen sin medi...  25 ago.
# 34  ¿Y ya lo saben los familiares de los más de 60...  25 ago.
# 41  ¡Andrés Manuel, ya deja de mentir! Tú no tiene...  25 ago.
# 42  @lopezobrador_  Se ha metido en toda área meno...  25 ago.
# 43  @lopezobrador_  No sé como dirigirme con usted...  25 ago.
# 44  Ya hay medicinas para tratamiento oncológico?\...  25 ago.
# 45  Pinches chairos como son pendej0s.\nNo pagan n...  25 ago.
# 46               Donde quedó la lana de los moches???  25 ago.
# 47  Mucha pinche conferencia,  mucho pinche discur...  25 ago.
# 57  Los mexicanos queremos resultados en economía,...  25 ago.
# 58  En usted confiamos. La guerra sucia no va a im...  25 ago.
# 64  Hay que definir que es ser “bueno”. En mi conc...  25 ago.
# 65                Ni un peso a este gobierno corrupto  25 ago.
# 66  Bueno para nada que eres miserable! #amlorenuncia  25 ago.
# 67  El humanista que no quiere que hablemos del CO...  25 ago.
# 68  Chng t mdr animales tus familiares obesos y fe...  25 ago.
# 69                   AMLO el pueblo está contigo 🇲🇽🇲🇽  25 ago.
# 70       Los niños con cáncer no tienen medicamentos.  25 ago.
# 71  El Tigre sigue contigo querido presidente somo...  25 ago.
# 72  Todos los dias, el mismo modito y tonito, nada...  25 ago.
# 73  Apoyemos a nuestros Presidente comprando un bo...  25 ago.
# 74  Este circo es ofensivo! Y daña a todo méxico, ...  25 ago.
# 76  Ha de ser por la convicción de seguir mintiend...  25 ago.
# 77  Gracias, mi querido presidente, porque sólo  u...  25 ago.
# 78                         Buen días señor presidente  25 ago.
#
#                 User
# 0     @Brigitte_Grey
# 1      @juancarlosgt
# 3    @jceciliatorres
# 5        @ara_robles
# 8        @LuisEVera3
# 11     @ChumelTorres
# 12       @JhonBislon
# 25  @MRAngelmoreno80
# 26    @germancuriel5
# 27        @rodsainz1
# 28  @ClaudiaRominaCV
# 29    @laishawilkins
# 30  @abrahamchilleta
# 31      @donpasapunk
# 32   @Alecx_Bautista
# 33      @Quetzal0518
# 34       @francarima
# 41        @aracelibs
# 42   @ALICIA90014450
# 43   @ALICIA90014450
# 44  @OsvaldoLuciotto
# 45    @LicValebertha
# 46        @oscarrb35
# 47          @SoyYo_J
# 57      @Elegido123_
# 58     @ElReyTuitero
# 64       @jesusgro_9
# 65      @Fer_nand123
# 66  @Paulina20828768
# 67      @RiosCorona1
# 68  @NtreBromaYBroma
# 69  @RenMora94009563
# 70         @Hugo_MS1
# 71       @gabvvsweet
# 72  @IrmaGar48196037
# 73     @franknity007
# 74    @patricio_em20
# 76     @Roxy08570414
# 77  @MaraMarcelinad1
# 78       @Mostafat19

# %%
df.sort_values(by=["Date"])
# Out:
#                                                Content    Date  \
# 831  @lopezobrador_  tienes cuatro meses por delant...  1 ago.
# 830  @lopezobrador_ anunciará el 15 de Septiembre q...  1 ago.
# 805  @lopezobrador_  al tener influencia en millone...  1 ago.
# 806  Pues vayan tomando nota que ya hay mucha escas...  1 ago.
# 807  @lopezobrador_  sin autoridad moral para criti...  1 ago.
# ..                                                 ...     ...
# 496  ¿Y si mejor dejas de hacerte pendejo, y se tom...  9 ago.
# 497  Es como si el Iceberg hace un homenaje para lo...  9 ago.
# 498  Eres perverso López, todavía recordamos que de...  9 ago.
# 566  Lo bueno es que también se termina la Corrupci...  9 ago.
# 519  Ponga el ejemplo y no ande turisteando por tod...  9 ago.
#
#                  User
# 831     @ErnestoBNava
# 830       @ElGuyTrejo
# 805        @davicinsc
# 806  @SusanaH94097821
# 807        @davicinsc
# ..                ...
# 496        @mazacuato
# 497    @DonPorfifirio
# 498      @Quetzal0518
# 566       @ThisIsLieb
# 519      @AleLadyBird
#
# [832 rows x 3 columns]

# %%
df.to_csv("Tweets.csv", index = False)
